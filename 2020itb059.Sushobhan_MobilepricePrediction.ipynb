# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Mobile phone price.csv')
df
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1  \
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %%
X= df.iloc[:,0:7]

X['Brand'] = pd.factorize(X['Brand'])[0]
X['Model'] = pd.factorize(X['Model'])[0]

# %%
print(X.columns)
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)'],
#       dtype='object')

# %%
X['Storage '] = X['Storage '].str.replace('GB', '')
X['Storage '] = X['Storage '].astype('int64')
X['RAM '] = X['RAM '].str.replace('GB', '')
X['RAM '] = X['RAM '].astype('int64')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    int64
#  1   Model                   407 non-null    int64
#  2   Storage                 407 non-null    int64
#  3   RAM                     407 non-null    int64
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 22.4+ KB

# %%
for i in range(len(X['Screen Size (inches)'])):
    a=""
    s=X['Screen Size (inches)'][i]
    for j in range(len(s)):
        if(s[j]!=' '):
            a=a+s[j]
        else:
            break
    X['Screen Size (inches)'][i]=a
X['Screen Size (inches)']
# Out:
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\2592431841.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Screen Size (inches)'][i]=a
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\2592431841.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Screen Size (inches)'][i]=a
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\2592431841.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
X['Screen Size (inches)']=X['Screen Size (inches)'].astype(float)
print(X['Screen Size (inches)'].dtype)
# Out:
# float64

# %%
for i in range(len(X['Camera (MP)'])):
    a=""
    s=X['Camera (MP)'][i]
    
    for j in range(len(s)):
        if(s[j]!='+' and s[j]!='M'):
            a=a+s[j]
        else:
            break
    X['Camera (MP)'][i]=a
X['Camera (MP)']
# Out:
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\1698498929.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Camera (MP)'][i]=a
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\1698498929.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Camera (MP)'][i]=a
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\1698498929.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Camera (MP)'][i]=a
# ...

# %%
X
# Out:
#      Brand  Model  Storage   RAM   Screen Size (inches) Camera (MP)
# 0        0      0       128     6                  6.10         12   \
# 1        1      1       256    12                  6.80        108
# 2        2      2       128     8                  6.70         48
# 3        3      3       128     6                  6.67         64
# 4        4      4       128     8                  6.40         50
# ..     ...    ...       ...   ...                   ...         ...
# 402      1    222       128     8                  6.70          12
# 403      3    236       128     6                  6.57          48
# 404      0    237       128     6                  6.70          12
# 405      5    238       128     8                  6.40          48
# 406      1    199       128     6                  6.70          48
#
#      Battery Capacity (mAh)
# 0                      3095
# 1                      5000
# 2                      4500
# 3                      5020
# ...

# %%
X['Camera (MP)']=X['Camera (MP)'].astype(float)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    int64
#  1   Model                   407 non-null    int64
#  2   Storage                 407 non-null    int64
#  3   RAM                     407 non-null    int64
#  4   Screen Size (inches)    407 non-null    float64
#  5   Camera (MP)             407 non-null    float64
#  6   Battery Capacity (mAh)  407 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 22.4 KB

# %%
Y=df.iloc[:,-1]
Y
# Out:
# 0       999
# 1      1199
# 2       899
# 3       279
# 4       799
#        ...
# 402    1049
# 403     349
# 404    1099
# 405     429
# 406     649
# Name: Price ($), Length: 407, dtype: object

# %%
for i in range(len(Y)):
    a=""
    s=Y[i]
    for j in range(len(s)):
        if(s[j]!='$' and s[j]!=','):
            a=a+s[j]
        elif(s[j]==' '):
            break
            
    Y[i]=a        
print(Y)
# Out:
# 0       999
# 1      1199
# 2       899
# 3       279
# 4       799
#        ...
# 402    1049
# 403     349
# 404    1099
# 405     429
# 406     649
# Name: Price ($), Length: 407, dtype: object
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\4283674419.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i]=a
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\4283674419.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i]=a
# C:\Users\susho\AppData\Local\Temp\ipykernel_24220\4283674419.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
Y= Y.astype('int64')
Y.dtype
# Out:
# dtype('int64')

# %%
X
# Out:
#      Brand  Model  Storage   RAM   Screen Size (inches)  Camera (MP)
# 0        0      0       128     6                  6.10         12.0  \
# 1        1      1       256    12                  6.80        108.0
# 2        2      2       128     8                  6.70         48.0
# 3        3      3       128     6                  6.67         64.0
# 4        4      4       128     8                  6.40         50.0
# ..     ...    ...       ...   ...                   ...          ...
# 402      1    222       128     8                  6.70         12.0
# 403      3    236       128     6                  6.57         48.0
# 404      0    237       128     6                  6.70         12.0
# 405      5    238       128     8                  6.40         48.0
# 406      1    199       128     6                  6.70         48.0
#
#      Battery Capacity (mAh)
# 0                      3095
# 1                      5000
# 2                      4500
# ...

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size= 0.25, random_state=0)  
  
# feature Scaling  
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()  
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor 
  
regressor = DecisionTreeRegressor(random_state = 0) 
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred_list = []

# Iterate over each row in x_test and predict the corresponding output value
for row in x_test:
    # Reshape the row to have a shape of (1, n_features) to match the expected input shape of the predict method
    row = row.reshape(1, -1)
    # Use the trained regressor to make a prediction for the current row
    y_pred = regressor.predict(row)
    print(y_pred)
    # Append the predicted value to the list
    y_pred_list.append(y_pred[0])  # The predicted value is a 1-dimensional array with a single element, so we extract the element using indexing

y_pred_array = np.array(y_pred_list)
# Out:
# [99.]
# [199.]
# [549.]
# [265.66666667]
# [184.]
# [699.]
# [329.]
# [141.5]
# [164.]
# [799.]
# [1199.]
# [139.]
# [1099.]
# [449.]
# [384.]
# [149.]
# [449.]
# [249.]
# [349.]
# [299.]
# [179.]
# [199.]
# [699.]
# [299.]
# [279.]
# [219.]
# [549.]
# [499.]
# [384.]
# [399.]
# [149.]
# [1199.]
# [249.]
# [749.]
# [399.]
# [149.]
# [449.]
# [399.]
# [279.]
# [455.66666667]
# [149.]
# [399.]
# [329.]
# [249.]
# [1099.]
# [1199.]
# [799.]
# [279.]
# [429.]
# [244.]
# [199.]
# [349.]
# [329.]
# [1049.]
# [399.]
# [399.]
# [162.33333333]
# [599.]
# [1099.]
# [199.]
# [399.]
# [139.]
# [699.]
# [799.]
# [349.]
# [699.]
# [449.]
# [329.]
# [202.33333333]
# [239.]
# [799.]
# [219.]
# [649.]
# [449.]
# [259.]
# [269.]
# [532.33333333]
# [209.]
# [129.]
# [699.]
# [532.33333333]
# [299.]
# [239.]
# [164.]
# [699.]
# [199.]
# [249.]
# [349.]
# [265.66666667]
# [159.]
# [199.]
# [189.]
# [169.]
# [279.]
# [249.]
# [799.]
# [199.]
# [314.]
# [199.]
# [499.]
# [299.]
# [299.]

# %%
x_test.shape
# Out:
# (102, 7)

# %%
y_test=np.array(y_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae = mean_absolute_error(y_test, y_pred_array)

# Calculate the accuracy in terms of percentage
accuracy = (1 - mae / y_test.mean()) * 100

print("Accuracy: {:.2f}%".format(accuracy))
# Out:
# Accuracy: 85.30%
